# %%
from SelBotHistory import SelBot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-bf99fe91740c> in <module>()
# ----> 1 from SelBotHistory import SelBot
#
# /media/sf_pjt/GitHub/Research-Salvage-Autos/SelBotHistory.py in <module>()
#       5 from bs4 import BeautifulSoup
#       6 import json , datetime , os , time , glob , traceback
# ----> 7 import pandas as pd
#       8 from tqdm import tqdm
#       9 from random import randint
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/__init__.py in <module>()
#      40 import pandas.core.config_init
#      41
# ---> 42 from pandas.core.api import *
#      43 from pandas.core.sparse.api import *
#      44 from pandas.tseries.api import *
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/api.py in <module>()
#       8 from pandas.core.dtypes.missing import isna, isnull, notna, notnull
#       9 from pandas.core.arrays import Categorical
# ...

# %%
name = 'Desoto'

bot = SelBot(name)
bot.run_process(pages = 10)
# Out:
# Error at: 0
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 1
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 2
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 3
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 4
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 5
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 6
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 7
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 8
# Error details: Message: Unable to locate element: .item.next
#
# Error at: 9
# Error details: Message: Unable to locate element: .item.next
#
# All work done

# %% [raw]
# make
# brand
# model
# damage
# sell price
# repair cost
# state
# city
#
#
# city caracteristic doesn't depends on the sale price
#
# city information - median income

# %% [raw]
# # Cadillac - 800
#
# # Chrysler - 1374
# # Citroen - 1
# # Daewoo - 4
# # Datsun - 9
# # Delorean - 1
# # Desoto - 1
# # Eagle -3
# # Esse - 1
# # Fisker Automotive - 1
#
#
# # Ferrari- 11
# # Fiat 70
#
#
#
# #Dodge 2028 - #1399
#
# #GMC 666
#
# #Isuzu 91
#
# Ford 5105
# Chevrolet 4680
#
# Honda 5364 #99
#
# #Hyundai 2238
#
# #Infiniti 755
#
# #Jaguar 241
#
# #Jayco 2
#
# #Jeep 1956
# #KIA 1495
#
# #Lamborghini 5
#
# #Land Rover 369
#
# #Lexus 1484
#
# #Lincoln 481
#
# #Maserati 39
#
# #Mazda 1281
#
# Mclaren Automotive 1
#
# #Mercedes-Benz 1984
#
# #Mercury 356
#
# #Mini 281
#
#
# #Mitsubishi 636
#
# #Nissan 4628 - 100
#
# #Northwood 1
#
# #Oldsmobile 108
# Packard 3
# Plymouth 35
# #Pontiac 734
#
#
# Porsche
#
# Renault
#
# Rolls-Royce
#
# Saab
#
# Saturn
#
# Scion
#
# Seadoo
#
# Shel
#
# Smart
#
#
# Subaru
#
# Suzuki
#
# Sylvan
#
# Tesla
#
# Toyota
#
# Utility
#
# VPG
#
# Volkswagen
#
# Volvo
#
# Wabash
